# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
#print(cities)
# Out:
# 743

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
#for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
#    if (i % 50 == 0 and i >= 50):
#        set_count += 1
#        record_count = 1
#        time.sleep(60)

    # Create endpoint URL with each city.
#    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_desc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | beian
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | torbay
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | yelanskiy
# Processing Record 6 of Set 1 | honiara
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | severo-kurilsk
# Processing Record 9 of Set 1 | chicama
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | coquimbo
# Processing Record 12 of Set 1 | springbok
# Processing Record 13 of Set 1 | gizo
# Processing Record 14 of Set 1 | airai
# Processing Record 15 of Set 1 | chadiza
# Processing Record 16 of Set 1 | sept-iles
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | ahipara
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | saint-louis
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | keuruu
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | santa cruz
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | houma
# Processing Record 30 of Set 1 | port moresby
# Processing Record 31 of Set 1 | katsuura
# Processing Record 32 of Set 1 | ayagoz
# Processing Record 33 of Set 1 | leningradskiy
# Processing Record 34 of Set 1 | christchurch
# Processing Record 35 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 1 | vilhena
# Processing Record 37 of Set 1 | manono
# Processing Record 38 of Set 1 | fort morgan
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | cherskiy
# Processing Record 42 of Set 1 | tuatapere
# Processing Record 43 of Set 1 | beloha
# Processing Record 44 of Set 1 | lompoc
# Processing Record 45 of Set 1 | shenjiamen
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | san quintin
# Processing Record 48 of Set 1 | saldanha
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | zheleznodorozhnyy
# Processing Record 1 of Set 2 | merauke
# Processing Record 2 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 3 of Set 2 | upata
# Processing Record 4 of Set 2 | silifke
# Processing Record 5 of Set 2 | mareeba
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | ahome
# Processing Record 8 of Set 2 | arkhangelsk
# Processing Record 9 of Set 2 | vila franca do campo
# Processing Record 10 of Set 2 | verkhnyaya toyma
# Processing Record 11 of Set 2 | lagoa
# Processing Record 12 of Set 2 | quang ngai
# Processing Record 13 of Set 2 | dovers
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | tasiilaq
# Processing Record 17 of Set 2 | rabaul
# Processing Record 18 of Set 2 | plettenberg bay
# Processing Record 19 of Set 2 | norman wells
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | ilulissat
# Processing Record 22 of Set 2 | lebu
# Processing Record 23 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | sao jose dos campos
# Processing Record 26 of Set 2 | busselton
# Processing Record 27 of Set 2 | teguldet
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 30 of Set 2 | booue
# Processing Record 31 of Set 2 | yomitan
# City not found. Skipping...
# Processing Record 32 of Set 2 | iqaluit
# Processing Record 33 of Set 2 | grindavik
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | kutum
# Processing Record 36 of Set 2 | khatanga
# Processing Record 37 of Set 2 | cidreira
# Processing Record 38 of Set 2 | miraflores
# Processing Record 39 of Set 2 | mataura
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 2 | adra
# Processing Record 43 of Set 2 | gilazi
# City not found. Skipping...
# Processing Record 44 of Set 2 | north bend
# Processing Record 45 of Set 2 | abiy adi
# City not found. Skipping...
# Processing Record 46 of Set 2 | jinxiang
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | jurado
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 50 of Set 2 | chontalpa
# Processing Record 1 of Set 3 | punta arenas
# Processing Record 2 of Set 3 | saint george
# Processing Record 3 of Set 3 | salinopolis
# Processing Record 4 of Set 3 | xining
# Processing Record 5 of Set 3 | coahuayana
# Processing Record 6 of Set 3 | kapit
# Processing Record 7 of Set 3 | elko
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | cayenne
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | isangel
# Processing Record 12 of Set 3 | provideniya
# Processing Record 13 of Set 3 | hilo
# Processing Record 14 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 3 | balkhash
# Processing Record 16 of Set 3 | itarema
# Processing Record 17 of Set 3 | iranshahr
# Processing Record 18 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 3 | geraldton
# Processing Record 20 of Set 3 | rocha
# Processing Record 21 of Set 3 | ust-maya
# Processing Record 22 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 3 | morristown
# Processing Record 24 of Set 3 | cape town
# Processing Record 25 of Set 3 | yumen
# Processing Record 26 of Set 3 | alofi
# Processing Record 27 of Set 3 | coihaique
# Processing Record 28 of Set 3 | sibut
# Processing Record 29 of Set 3 | porbandar
# Processing Record 30 of Set 3 | isla vista
# Processing Record 31 of Set 3 | upernavik
# Processing Record 32 of Set 3 | kinsale
# Processing Record 33 of Set 3 | sai buri
# Processing Record 34 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | krasnoselkup
# Processing Record 37 of Set 3 | kodiak
# Processing Record 38 of Set 3 | marsa matruh
# Processing Record 39 of Set 3 | batagay-alyta
# Processing Record 40 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 3 | fortuna
# Processing Record 42 of Set 3 | tura
# Processing Record 43 of Set 3 | pilar
# Processing Record 44 of Set 3 | carnarvon
# Processing Record 45 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 3 | russell
# Processing Record 47 of Set 3 | bambous virieux
# Processing Record 48 of Set 3 | zhaotong
# Processing Record 49 of Set 3 | bandarbeyla
# Processing Record 50 of Set 3 | yining
# Processing Record 1 of Set 4 | lander
# Processing Record 2 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 4 | barrow
# Processing Record 4 of Set 4 | klyuchi
# Processing Record 5 of Set 4 | salalah
# Processing Record 6 of Set 4 | san andres
# Processing Record 7 of Set 4 | atuona
# Processing Record 8 of Set 4 | bethel
# Processing Record 9 of Set 4 | santiago del estero
# Processing Record 10 of Set 4 | muros
# Processing Record 11 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 4 | lima
# Processing Record 13 of Set 4 | qaanaaq
# Processing Record 14 of Set 4 | xingyi
# Processing Record 15 of Set 4 | mizpe ramon
# City not found. Skipping...
# Processing Record 16 of Set 4 | puerto maldonado
# Processing Record 17 of Set 4 | san policarpo
# Processing Record 18 of Set 4 | pevek
# Processing Record 19 of Set 4 | chimbote
# Processing Record 20 of Set 4 | hamilton
# Processing Record 21 of Set 4 | mount gambier
# Processing Record 22 of Set 4 | tautira
# Processing Record 23 of Set 4 | banjar
# Processing Record 24 of Set 4 | sao filipe
# Processing Record 25 of Set 4 | hami
# Processing Record 26 of Set 4 | kitale
# Processing Record 27 of Set 4 | half moon bay
# Processing Record 28 of Set 4 | ucluelet
# Processing Record 29 of Set 4 | ust-nera
# Processing Record 30 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 4 | cabedelo
# Processing Record 32 of Set 4 | nikolskoye
# Processing Record 33 of Set 4 | ancud
# Processing Record 34 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 4 | babra
# Processing Record 36 of Set 4 | pisco
# Processing Record 37 of Set 4 | port alfred
# Processing Record 38 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 4 | castro
# Processing Record 40 of Set 4 | sinnamary
# Processing Record 41 of Set 4 | sambava
# Processing Record 42 of Set 4 | fort dix
# Processing Record 43 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 44 of Set 4 | clarence town
# Processing Record 45 of Set 4 | caravelas
# Processing Record 46 of Set 4 | asau
# Processing Record 47 of Set 4 | perth
# Processing Record 48 of Set 4 | taft
# Processing Record 49 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 4 | kaitangata
# Processing Record 1 of Set 5 | zheleznogorsk
# Processing Record 2 of Set 5 | los llanos de aridane
# Processing Record 3 of Set 5 | zeya
# Processing Record 4 of Set 5 | necochea
# Processing Record 5 of Set 5 | bindura
# Processing Record 6 of Set 5 | port lincoln
# Processing Record 7 of Set 5 | mtambile
# Processing Record 8 of Set 5 | komsomolskiy
# Processing Record 9 of Set 5 | haines junction
# Processing Record 10 of Set 5 | pacific grove
# Processing Record 11 of Set 5 | vao
# Processing Record 12 of Set 5 | morant bay
# Processing Record 13 of Set 5 | puerto suarez
# Processing Record 14 of Set 5 | jati
# Processing Record 15 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 5 | banda aceh
# Processing Record 17 of Set 5 | talnakh
# Processing Record 18 of Set 5 | pacifica
# Processing Record 19 of Set 5 | namatanai
# Processing Record 20 of Set 5 | henties bay
# Processing Record 21 of Set 5 | dubbo
# Processing Record 22 of Set 5 | kyshtovka
# Processing Record 23 of Set 5 | poya
# Processing Record 24 of Set 5 | clyde river
# Processing Record 25 of Set 5 | kieta
# Processing Record 26 of Set 5 | langsa
# Processing Record 27 of Set 5 | kununurra
# Processing Record 28 of Set 5 | taywarah
# Processing Record 29 of Set 5 | simpang empat
# Processing Record 30 of Set 5 | charters towers
# Processing Record 31 of Set 5 | alenquer
# Processing Record 32 of Set 5 | klaksvik
# Processing Record 33 of Set 5 | rio gallegos
# Processing Record 34 of Set 5 | arraial do cabo
# Processing Record 35 of Set 5 | ndioum
# Processing Record 36 of Set 5 | wajima
# Processing Record 37 of Set 5 | liverpool
# Processing Record 38 of Set 5 | casino
# Processing Record 39 of Set 5 | flin flon
# Processing Record 40 of Set 5 | verkhnevilyuysk
# Processing Record 41 of Set 5 | garcia
# Processing Record 42 of Set 5 | gat
# Processing Record 43 of Set 5 | cockburn town
# Processing Record 44 of Set 5 | faanui
# Processing Record 45 of Set 5 | souillac
# Processing Record 46 of Set 5 | bengkulu
# Processing Record 47 of Set 5 | shingu
# Processing Record 48 of Set 5 | shimanovsk
# Processing Record 49 of Set 5 | hofn
# Processing Record 50 of Set 5 | jiroft
# City not found. Skipping...
# Processing Record 1 of Set 6 | college
# Processing Record 2 of Set 6 | belfast
# Processing Record 3 of Set 6 | denpasar
# Processing Record 4 of Set 6 | abalak
# Processing Record 5 of Set 6 | belaya gora
# Processing Record 6 of Set 6 | bismil
# Processing Record 7 of Set 6 | am timan
# Processing Record 8 of Set 6 | lakes entrance
# Processing Record 9 of Set 6 | atar
# Processing Record 10 of Set 6 | ishigaki
# Processing Record 11 of Set 6 | tawau
# Processing Record 12 of Set 6 | avera
# Processing Record 13 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 6 | charlottetown
# Processing Record 16 of Set 6 | yarada
# Processing Record 17 of Set 6 | mahibadhoo
# Processing Record 18 of Set 6 | padang
# Processing Record 19 of Set 6 | marietta
# Processing Record 20 of Set 6 | santa isabel
# Processing Record 21 of Set 6 | keflavik
# Processing Record 22 of Set 6 | pokhara
# Processing Record 23 of Set 6 | dois vizinhos
# Processing Record 24 of Set 6 | athabasca
# Processing Record 25 of Set 6 | nara
# Processing Record 26 of Set 6 | portland
# Processing Record 27 of Set 6 | meridian
# Processing Record 28 of Set 6 | ponta do sol
# Processing Record 29 of Set 6 | bojnurd
# Processing Record 30 of Set 6 | port blair
# Processing Record 31 of Set 6 | fort nelson
# Processing Record 32 of Set 6 | prince rupert
# Processing Record 33 of Set 6 | moindou
# Processing Record 34 of Set 6 | mar del plata
# Processing Record 35 of Set 6 | ponta delgada
# Processing Record 36 of Set 6 | gander
# Processing Record 37 of Set 6 | rio grande
# Processing Record 38 of Set 6 | kavieng
# Processing Record 39 of Set 6 | inhambane
# Processing Record 40 of Set 6 | istria
# Processing Record 41 of Set 6 | sistranda
# Processing Record 42 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 43 of Set 6 | nelson bay
# Processing Record 44 of Set 6 | laureles
# Processing Record 45 of Set 6 | tual
# Processing Record 46 of Set 6 | bathsheba
# Processing Record 47 of Set 6 | balangir
# Processing Record 48 of Set 6 | panambi
# Processing Record 49 of Set 6 | panalingaan
# Processing Record 50 of Set 6 | lavrentiya
# Processing Record 1 of Set 7 | nantucket
# Processing Record 2 of Set 7 | valleyview
# Processing Record 3 of Set 7 | isabela
# Processing Record 4 of Set 7 | stavern
# Processing Record 5 of Set 7 | bukama
# Processing Record 6 of Set 7 | kodinsk
# Processing Record 7 of Set 7 | laguna
# Processing Record 8 of Set 7 | sandnessjoen
# Processing Record 9 of Set 7 | vastervik
# City not found. Skipping...
# Processing Record 10 of Set 7 | mitsamiouli
# Processing Record 11 of Set 7 | buenos aires
# Processing Record 12 of Set 7 | comodoro rivadavia
# Processing Record 13 of Set 7 | yellamanchili
# City not found. Skipping...
# Processing Record 14 of Set 7 | filingue
# Processing Record 15 of Set 7 | olafsvik
# Processing Record 16 of Set 7 | gorodovikovsk
# Processing Record 17 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 19 of Set 7 | akyab
# Processing Record 20 of Set 7 | lesnoy
# Processing Record 21 of Set 7 | hokitika
# Processing Record 22 of Set 7 | ruteng
# Processing Record 23 of Set 7 | mecca
# Processing Record 24 of Set 7 | chara
# Processing Record 25 of Set 7 | jieshi
# Processing Record 26 of Set 7 | mogadishu
# Processing Record 27 of Set 7 | santa ines
# Processing Record 28 of Set 7 | mago
# Processing Record 29 of Set 7 | haicheng
# Processing Record 30 of Set 7 | yeniseysk
# Processing Record 31 of Set 7 | jinchang
# Processing Record 32 of Set 7 | vacaria
# Processing Record 33 of Set 7 | sisimiut
# Processing Record 34 of Set 7 | noumea
# Processing Record 35 of Set 7 | ketchikan
# Processing Record 36 of Set 7 | oslomej
# Processing Record 37 of Set 7 | grand-lahou
# Processing Record 38 of Set 7 | ostrovnoy
# Processing Record 39 of Set 7 | amapa
# Processing Record 40 of Set 7 | kruisfontein
# Processing Record 41 of Set 7 | socorro
# Processing Record 42 of Set 7 | labuan
# Processing Record 43 of Set 7 | ixtapa
# Processing Record 44 of Set 7 | amga
# Processing Record 45 of Set 7 | khandyga
# Processing Record 46 of Set 7 | colquechaca
# Processing Record 47 of Set 7 | sisophon
# Processing Record 48 of Set 7 | polovinnoye
# Processing Record 49 of Set 7 | alta floresta
# Processing Record 50 of Set 7 | coetupo
# City not found. Skipping...
# Processing Record 1 of Set 8 | kedrovyy
# Processing Record 2 of Set 8 | cam ranh
# Processing Record 3 of Set 8 | safaga
# Processing Record 4 of Set 8 | korla
# Processing Record 5 of Set 8 | vostok
# Processing Record 6 of Set 8 | koumac
# Processing Record 7 of Set 8 | hushitai
# Processing Record 8 of Set 8 | praya
# Processing Record 9 of Set 8 | muzaffargarh
# Processing Record 10 of Set 8 | dalrymple
# Processing Record 11 of Set 8 | fonte boa
# Processing Record 12 of Set 8 | grand gaube
# Processing Record 13 of Set 8 | brae
# Processing Record 14 of Set 8 | mount isa
# Processing Record 15 of Set 8 | kapuskasing
# Processing Record 16 of Set 8 | starokozache
# Processing Record 17 of Set 8 | kavaratti
# Processing Record 18 of Set 8 | chumikan
# Processing Record 19 of Set 8 | lokosovo
# Processing Record 20 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 8 | tari
# Processing Record 22 of Set 8 | la llanada
# Processing Record 23 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 24 of Set 8 | martaban
# Processing Record 25 of Set 8 | kupang
# Processing Record 26 of Set 8 | palmer
# Processing Record 27 of Set 8 | watertown
# Processing Record 28 of Set 8 | denizli
# Processing Record 29 of Set 8 | saint-augustin
# Processing Record 30 of Set 8 | san luis
# Processing Record 31 of Set 8 | kahului
# Processing Record 32 of Set 8 | tiksi
# Processing Record 33 of Set 8 | urumqi
# Processing Record 34 of Set 8 | tiznit
# Processing Record 35 of Set 8 | goderich
# Processing Record 36 of Set 8 | etaples
# Processing Record 37 of Set 8 | taoudenni
# Processing Record 38 of Set 8 | vardo
# Processing Record 39 of Set 8 | port hedland
# Processing Record 40 of Set 8 | cabra
# Processing Record 41 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 8 | fallon
# Processing Record 43 of Set 8 | sitka
# Processing Record 44 of Set 8 | cap malheureux
# Processing Record 45 of Set 8 | qianan
# Processing Record 46 of Set 8 | torzhok
# Processing Record 47 of Set 8 | pundaguitan
# Processing Record 48 of Set 8 | dunedin
# Processing Record 49 of Set 8 | vitoria da conquista
# Processing Record 50 of Set 8 | okandja
# City not found. Skipping...
# Processing Record 1 of Set 9 | udachnyy
# Processing Record 2 of Set 9 | san cristobal
# Processing Record 3 of Set 9 | tokonou
# Processing Record 4 of Set 9 | beringovskiy
# Processing Record 5 of Set 9 | puerto el triunfo
# Processing Record 6 of Set 9 | dongning
# Processing Record 7 of Set 9 | hay river
# Processing Record 8 of Set 9 | mendi
# Processing Record 9 of Set 9 | ust-tsilma
# Processing Record 10 of Set 9 | lorengau
# Processing Record 11 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 12 of Set 9 | grand baie
# Processing Record 13 of Set 9 | argentan
# Processing Record 14 of Set 9 | monrovia
# Processing Record 15 of Set 9 | tabory
# Processing Record 16 of Set 9 | kamaishi
# Processing Record 17 of Set 9 | porto novo
# Processing Record 18 of Set 9 | kabare
# Processing Record 19 of Set 9 | voh
# Processing Record 20 of Set 9 | quevedo
# Processing Record 21 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 22 of Set 9 | taltal
# Processing Record 23 of Set 9 | jujuy
# City not found. Skipping...
# Processing Record 24 of Set 9 | faya
# Processing Record 25 of Set 9 | sterling
# Processing Record 26 of Set 9 | ulaangom
# Processing Record 27 of Set 9 | te anau
# Processing Record 28 of Set 9 | yakeshi
# Processing Record 29 of Set 9 | menongue
# Processing Record 30 of Set 9 | barabash
# Processing Record 31 of Set 9 | egvekinot
# Processing Record 32 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 9 | ofunato
# Processing Record 34 of Set 9 | san pedro
# Processing Record 35 of Set 9 | havoysund
# Processing Record 36 of Set 9 | slonim
# Processing Record 37 of Set 9 | narsaq
# Processing Record 38 of Set 9 | tunduru
# City not found. Skipping...
# Processing Record 39 of Set 9 | longyearbyen
# Processing Record 40 of Set 9 | la ronge
# Processing Record 41 of Set 9 | derzhavinsk
# Processing Record 42 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 9 | bainbridge
# Processing Record 44 of Set 9 | kirakira
# Processing Record 45 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 9 | bhum
# Processing Record 47 of Set 9 | santa cruz del sur
# Processing Record 48 of Set 9 | yulara
# Processing Record 49 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 50 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 10 | lasa
# Processing Record 2 of Set 10 | calvinia
# Processing Record 3 of Set 10 | soe
# Processing Record 4 of Set 10 | the valley
# Processing Record 5 of Set 10 | tucuman
# Processing Record 6 of Set 10 | belmonte
# Processing Record 7 of Set 10 | bamiantong
# Processing Record 8 of Set 10 | jardim
# Processing Record 9 of Set 10 | bilibino
# Processing Record 10 of Set 10 | bambanglipuro
# Processing Record 11 of Set 10 | chokurdakh
# Processing Record 12 of Set 10 | ludvika
# Processing Record 13 of Set 10 | cap-aux-meules
# Processing Record 14 of Set 10 | la uribe
# City not found. Skipping...
# Processing Record 15 of Set 10 | da nang
# Processing Record 16 of Set 10 | rock sound
# Processing Record 17 of Set 10 | gaspe
# Processing Record 18 of Set 10 | dispur
# Processing Record 19 of Set 10 | sindal
# Processing Record 20 of Set 10 | yelovo
# Processing Record 21 of Set 10 | kudahuvadhoo
# Processing Record 22 of Set 10 | boende
# Processing Record 23 of Set 10 | kashi
# Processing Record 24 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 10 | hirara
# Processing Record 26 of Set 10 | quixada
# Processing Record 27 of Set 10 | ardakan
# Processing Record 28 of Set 10 | sidi ali
# Processing Record 29 of Set 10 | hualmay
# Processing Record 30 of Set 10 | mama
# Processing Record 31 of Set 10 | nouakchott
# Processing Record 32 of Set 10 | pareora
# Processing Record 33 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 34 of Set 10 | novikovo
# Processing Record 35 of Set 10 | mazagao
# Processing Record 36 of Set 10 | hasaki
# Processing Record 37 of Set 10 | bar harbor
# Processing Record 38 of Set 10 | kamalia
# Processing Record 39 of Set 10 | abonnema
# Processing Record 40 of Set 10 | bambamarca
# Processing Record 41 of Set 10 | kulhudhuffushi
# Processing Record 42 of Set 10 | nanning
# Processing Record 43 of Set 10 | concordia
# Processing Record 44 of Set 10 | chapais
# Processing Record 45 of Set 10 | maceio
# Processing Record 46 of Set 10 | inta
# Processing Record 47 of Set 10 | touros
# Processing Record 48 of Set 10 | dauphin
# Processing Record 49 of Set 10 | adeje
# Processing Record 50 of Set 10 | viedma
# Processing Record 1 of Set 11 | aasiaat
# Processing Record 2 of Set 11 | lata
# Processing Record 3 of Set 11 | askino
# Processing Record 4 of Set 11 | panuco
# Processing Record 5 of Set 11 | kigoma
# Processing Record 6 of Set 11 | manaus
# Processing Record 7 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 11 | san patricio
# Processing Record 9 of Set 11 | yar-sale
# Processing Record 10 of Set 11 | evensk
# Processing Record 11 of Set 11 | codrington
# Processing Record 12 of Set 11 | victoria
# Processing Record 13 of Set 11 | port hardy
# Processing Record 14 of Set 11 | fairbanks
# Processing Record 15 of Set 11 | kaeo
# Processing Record 16 of Set 11 | novyy urengoy
# Processing Record 17 of Set 11 | agrado
# Processing Record 18 of Set 11 | anadyr
# Processing Record 19 of Set 11 | seoul
# Processing Record 20 of Set 11 | nishihara
# Processing Record 21 of Set 11 | ust-kuyga
# Processing Record 22 of Set 11 | nanortalik
# Processing Record 23 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 11 | walvis bay
# Processing Record 25 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 11 | san rafael
# Processing Record 27 of Set 11 | hobbs
# Processing Record 28 of Set 11 | armidale
# Processing Record 29 of Set 11 | gympie
# Processing Record 30 of Set 11 | tangier
# Processing Record 31 of Set 11 | taksimo
# Processing Record 32 of Set 11 | onega
# Processing Record 33 of Set 11 | mumbwa
# Processing Record 34 of Set 11 | tagusao
# Processing Record 35 of Set 11 | srandakan
# Processing Record 36 of Set 11 | susanville
# Processing Record 37 of Set 11 | wasilla
# Processing Record 38 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 39 of Set 11 | mtwara
# Processing Record 40 of Set 11 | ippy
# Processing Record 41 of Set 11 | lesozavodsk
# Processing Record 42 of Set 11 | waterloo
# Processing Record 43 of Set 11 | salinas
# Processing Record 44 of Set 11 | acarau
# Processing Record 45 of Set 11 | qandala
# Processing Record 46 of Set 11 | mount pleasant
# Processing Record 47 of Set 11 | sebrovo
# Processing Record 48 of Set 11 | gainesville
# Processing Record 49 of Set 11 | gamba
# Processing Record 50 of Set 11 | zhigansk
# Processing Record 1 of Set 12 | shihezi
# Processing Record 2 of Set 12 | hosdurga
# Processing Record 3 of Set 12 | sorland
# Processing Record 4 of Set 12 | vanimo
# Processing Record 5 of Set 12 | bonfim
# Processing Record 6 of Set 12 | altay
# Processing Record 7 of Set 12 | lafia
# Processing Record 8 of Set 12 | srednekolymsk
# Processing Record 9 of Set 12 | turukhansk
# Processing Record 10 of Set 12 | kushchevskaya
# Processing Record 11 of Set 12 | sungairaya
# Processing Record 12 of Set 12 | yithion
# City not found. Skipping...
# Processing Record 13 of Set 12 | chaoyang
# Processing Record 14 of Set 12 | felipe carrillo puerto
# Processing Record 15 of Set 12 | meulaboh
# Processing Record 16 of Set 12 | mahanoro
# Processing Record 17 of Set 12 | luderitz
# Processing Record 18 of Set 12 | riverton
# Processing Record 19 of Set 12 | pestravka
# Processing Record 20 of Set 12 | port-gentil
# Processing Record 21 of Set 12 | matay
# Processing Record 22 of Set 12 | muravlenko
# Processing Record 23 of Set 12 | kristiinankaupunki
# Processing Record 24 of Set 12 | buritizeiro
# Processing Record 25 of Set 12 | ambon
# Processing Record 26 of Set 12 | katobu
# Processing Record 27 of Set 12 | sibolga
# Processing Record 28 of Set 12 | aklavik
# Processing Record 29 of Set 12 | ekibastuz
# Processing Record 30 of Set 12 | westport
# Processing Record 31 of Set 12 | naze
# Processing Record 32 of Set 12 | mongu
# Processing Record 33 of Set 12 | ahuimanu
# Processing Record 34 of Set 12 | new iberia
# Processing Record 35 of Set 12 | gweta
# Processing Record 36 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 37 of Set 12 | mezimesti
# Processing Record 38 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 39 of Set 12 | daru
# Processing Record 40 of Set 12 | sergeyevka
# Processing Record 41 of Set 12 | bom jesus
# Processing Record 42 of Set 12 | richards bay
# Processing Record 43 of Set 12 | duz
# City not found. Skipping...
# Processing Record 44 of Set 12 | labuhan
# Processing Record 45 of Set 12 | ossora
# Processing Record 46 of Set 12 | uruzgan
# Processing Record 47 of Set 12 | poum
# Processing Record 48 of Set 12 | nadym
# Processing Record 49 of Set 12 | namibe
# Processing Record 50 of Set 12 | roald
# Processing Record 1 of Set 13 | jiuquan
# Processing Record 2 of Set 13 | bilma
# Processing Record 3 of Set 13 | deputatskiy
# Processing Record 4 of Set 13 | mehamn
# Processing Record 5 of Set 13 | esperance
# Processing Record 6 of Set 13 | otkaznoye
# Processing Record 7 of Set 13 | misratah
# Processing Record 8 of Set 13 | san isidro
# Processing Record 9 of Set 13 | iida
# Processing Record 10 of Set 13 | san-pedro
# Processing Record 11 of Set 13 | sola
# Processing Record 12 of Set 13 | ulladulla
# Processing Record 13 of Set 13 | impfondo
# Processing Record 14 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 15 of Set 13 | teguise
# Processing Record 16 of Set 13 | samarai
# Processing Record 17 of Set 13 | armacao de pera
# Processing Record 18 of Set 13 | cao bang
# Processing Record 19 of Set 13 | nepalganj
# City not found. Skipping...
# Processing Record 20 of Set 13 | nemuro
# Processing Record 21 of Set 13 | binga
# Processing Record 22 of Set 13 | oranjemund
# Processing Record 23 of Set 13 | bonthe
# Processing Record 24 of Set 13 | jambi
# Processing Record 25 of Set 13 | lumsden
# Processing Record 26 of Set 13 | asyut
# Processing Record 27 of Set 13 | beyneu
# Processing Record 28 of Set 13 | lucea
# Processing Record 29 of Set 13 | verkhniye tatyshly
# Processing Record 30 of Set 13 | panguna
# Processing Record 31 of Set 13 | wajir
# Processing Record 32 of Set 13 | kaduqli
# Processing Record 33 of Set 13 | dom pedro
# Processing Record 34 of Set 13 | pontes e lacerda
# Processing Record 35 of Set 13 | khromtau
# Processing Record 36 of Set 13 | devils lake
# Processing Record 37 of Set 13 | alyangula
# Processing Record 38 of Set 13 | missoula
# Processing Record 39 of Set 13 | fruitvale
# Processing Record 40 of Set 13 | coruripe
# Processing Record 41 of Set 13 | hanyang
# Processing Record 42 of Set 13 | aykhal
# Processing Record 43 of Set 13 | lazaro cardenas
# Processing Record 44 of Set 13 | escanaba
# Processing Record 45 of Set 13 | bahia blanca
# Processing Record 46 of Set 13 | barreirinha
# Processing Record 47 of Set 13 | boke
# Processing Record 48 of Set 13 | tianpeng
# Processing Record 49 of Set 13 | amarante do maranhao
# Processing Record 50 of Set 13 | magadi
# Processing Record 1 of Set 14 | mumford
# Processing Record 2 of Set 14 | tongliao
# Processing Record 3 of Set 14 | broome
# Processing Record 4 of Set 14 | mwanga
# Processing Record 5 of Set 14 | dicabisagan
# Processing Record 6 of Set 14 | bud
# Processing Record 7 of Set 14 | hailar
# Processing Record 8 of Set 14 | chaohu
# Processing Record 9 of Set 14 | waharoa
# Processing Record 10 of Set 14 | yei
# Processing Record 11 of Set 14 | gigmoto
# Processing Record 12 of Set 14 | dapaong
# Processing Record 13 of Set 14 | aksarka
# Processing Record 14 of Set 14 | batemans bay
# Processing Record 15 of Set 14 | guerrero negro
# Processing Record 16 of Set 14 | niamey
# Processing Record 17 of Set 14 | constitucion
# Processing Record 18 of Set 14 | darhan
# Processing Record 19 of Set 14 | gohpur
# Processing Record 20 of Set 14 | thabazimbi
# Processing Record 21 of Set 14 | tarko-sale
# Processing Record 22 of Set 14 | griffith
# Processing Record 23 of Set 14 | batticaloa
# Processing Record 24 of Set 14 | karpathos
# Processing Record 25 of Set 14 | oksfjord
# Processing Record 26 of Set 14 | okha
# Processing Record 27 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 29 of Set 14 | puerto del rosario
# Processing Record 30 of Set 14 | itapecerica
# Processing Record 31 of Set 14 | vila velha
# Processing Record 32 of Set 14 | ca mau
# Processing Record 33 of Set 14 | dwarka
# Processing Record 34 of Set 14 | tokzar
# City not found. Skipping...
# Processing Record 35 of Set 14 | benguela
# Processing Record 36 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 37 of Set 14 | sinjah
# City not found. Skipping...
# Processing Record 38 of Set 14 | kinel-cherkassy
# Processing Record 39 of Set 14 | maniitsoq
# Processing Record 40 of Set 14 | ureki
# Processing Record 41 of Set 14 | ushtobe
# Processing Record 42 of Set 14 | vallenar
# Processing Record 43 of Set 14 | sao joao da barra
# Processing Record 44 of Set 14 | gravdal
# Processing Record 45 of Set 14 | vestmanna
# Processing Record 46 of Set 14 | rognan
# Processing Record 47 of Set 14 | tevaitoa
# Processing Record 48 of Set 14 | la romana
# Processing Record 49 of Set 14 | debre tabor
# Processing Record 50 of Set 14 | huron
# Processing Record 1 of Set 15 | tiarei
# Processing Record 2 of Set 15 | krasnyy yar
# Processing Record 3 of Set 15 | la merced
# Processing Record 4 of Set 15 | niquero
# Processing Record 5 of Set 15 | port antonio
# Processing Record 6 of Set 15 | alice springs
# Processing Record 7 of Set 15 | lumphat
# Processing Record 8 of Set 15 | faridpur
# Processing Record 9 of Set 15 | palana
# Processing Record 10 of Set 15 | sukhobuzimskoye
# Processing Record 11 of Set 15 | sao leopoldo
# Processing Record 12 of Set 15 | yeppoon
# Processing Record 13 of Set 15 | mabaruma
# Processing Record 14 of Set 15 | gilgit
# Processing Record 15 of Set 15 | igrim
# Processing Record 16 of Set 15 | nsanje
# Processing Record 17 of Set 15 | spruce grove
# Processing Record 18 of Set 15 | broken hill
# Processing Record 19 of Set 15 | corrente
# Processing Record 20 of Set 15 | biskamzha
# Processing Record 21 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 15 | huaiyin
# Processing Record 23 of Set 15 | progreso
# Processing Record 24 of Set 15 | usinsk
# Processing Record 25 of Set 15 | fairview
# Processing Record 26 of Set 15 | kastamonu
# Processing Record 27 of Set 15 | port macquarie
# Processing Record 28 of Set 15 | sladkovo
# Processing Record 29 of Set 15 | emba
# Processing Record 30 of Set 15 | nouadhibou
# Processing Record 31 of Set 15 | fare
# Processing Record 32 of Set 15 | wichita falls
# Processing Record 33 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 34 of Set 15 | anloga
# Processing Record 35 of Set 15 | valparaiso
# Processing Record 36 of Set 15 | tahe
# Processing Record 37 of Set 15 | motala
# Processing Record 38 of Set 15 | marystown
# Processing Record 39 of Set 15 | bow island
# Processing Record 40 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 41 of Set 15 | husavik
# Processing Record 42 of Set 15 | dingle
# Processing Record 43 of Set 15 | jaicos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Beian      NO  63.6559    9.5683     52.00        87          75
# 1          Albany      US  42.6001  -73.9662     81.18        71          35
# 2          Torbay      CA  47.6666  -52.7314     72.37        72          75
# 3         Ushuaia      AR -54.8000  -68.3000     35.26        87          75
# 4       Yelanskiy      RU  56.8419   62.5014     55.78        93          20
# 5         Honiara      SB  -9.4333  159.9500     86.47        60           0
# 6           Kapaa      US  22.0752 -159.3190     84.52        67          20
# 7  Severo-Kurilsk      RU  50.6789  156.1250     56.01        88          55
# 8         Chicama      PE  -7.8447  -79.1469     59.54        83           9
# 9         Rikitea      PF -23.1203 -134.9692     72.25        76          93
#
#    Wind Speed Current Description
# 0        2.30       broken clouds
# 1        3.87    scattered clouds
# 2        9.22       broken clouds
# 3       16.11          light rain
# 4        6.04          few clouds
# 5        3.56           clear sky
# 6       14.97          few clouds
# 7        8.39       broken clouds
# 8        6.76           clear sky
# 9        8.59     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
