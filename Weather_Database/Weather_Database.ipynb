# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
#print(cities)
# Out:
# 756

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
#for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
#    if (i % 50 == 0 and i >= 50):
#        set_count += 1
#        record_count = 1
#        time.sleep(60)

    # Create endpoint URL with each city.
#    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_desc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 1 | moa
# Processing Record 3 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | vanimo
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | uige
# Processing Record 8 of Set 1 | fairbanks
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | meulaboh
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | bowen
# Processing Record 14 of Set 1 | hanko
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | san quintin
# Processing Record 20 of Set 1 | leningradskiy
# Processing Record 21 of Set 1 | kenai
# Processing Record 22 of Set 1 | sorong
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | nishihara
# Processing Record 26 of Set 1 | sitka
# Processing Record 27 of Set 1 | havre-saint-pierre
# Processing Record 28 of Set 1 | hefei
# Processing Record 29 of Set 1 | beidao
# Processing Record 30 of Set 1 | guantanamo
# Processing Record 31 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | pangnirtung
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | kamina
# Processing Record 36 of Set 1 | teya
# Processing Record 37 of Set 1 | ostrovnoy
# Processing Record 38 of Set 1 | gushikawa
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | kosa
# Processing Record 41 of Set 1 | nara
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | pitimbu
# Processing Record 45 of Set 1 | hithadhoo
# Processing Record 46 of Set 1 | okhotsk
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | faanui
# Processing Record 49 of Set 1 | ossora
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | anar darreh
# City not found. Skipping...
# Processing Record 2 of Set 2 | chokurdakh
# Processing Record 3 of Set 2 | georgetown
# Processing Record 4 of Set 2 | nadym
# Processing Record 5 of Set 2 | kulachi
# Processing Record 6 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 2 | kapoeta
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | verkhnyaya inta
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | yanchukan
# City not found. Skipping...
# Processing Record 14 of Set 2 | nueva helvecia
# Processing Record 15 of Set 2 | surt
# Processing Record 16 of Set 2 | haines junction
# Processing Record 17 of Set 2 | ahipara
# Processing Record 18 of Set 2 | amapa
# Processing Record 19 of Set 2 | savalou
# Processing Record 20 of Set 2 | onguday
# Processing Record 21 of Set 2 | iqaluit
# Processing Record 22 of Set 2 | palmerston
# Processing Record 23 of Set 2 | lasa
# Processing Record 24 of Set 2 | hofn
# Processing Record 25 of Set 2 | mahebourg
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | pevek
# Processing Record 28 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 2 | bethel
# Processing Record 30 of Set 2 | palana
# Processing Record 31 of Set 2 | lompoc
# Processing Record 32 of Set 2 | tuatapere
# Processing Record 33 of Set 2 | sinjar
# Processing Record 34 of Set 2 | ushuaia
# Processing Record 35 of Set 2 | danilov
# Processing Record 36 of Set 2 | dese
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | saint george
# Processing Record 39 of Set 2 | maceio
# Processing Record 40 of Set 2 | barrow
# Processing Record 41 of Set 2 | port alfred
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | kondinskoye
# Processing Record 45 of Set 2 | fortuna
# Processing Record 46 of Set 2 | poum
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | nikolskoye
# Processing Record 49 of Set 2 | lavrentiya
# Processing Record 50 of Set 2 | severo-kurilsk
# Processing Record 1 of Set 3 | hebi
# Processing Record 2 of Set 3 | aviles
# Processing Record 3 of Set 3 | manacor
# Processing Record 4 of Set 3 | tasiilaq
# Processing Record 5 of Set 3 | leshukonskoye
# Processing Record 6 of Set 3 | clyde river
# Processing Record 7 of Set 3 | puerto escondido
# Processing Record 8 of Set 3 | katsuura
# Processing Record 9 of Set 3 | half moon bay
# Processing Record 10 of Set 3 | souillac
# Processing Record 11 of Set 3 | erenhot
# Processing Record 12 of Set 3 | coihaique
# Processing Record 13 of Set 3 | klyuchevskiy
# Processing Record 14 of Set 3 | carutapera
# Processing Record 15 of Set 3 | bud
# Processing Record 16 of Set 3 | kahului
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | ende
# Processing Record 19 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 3 | shvartsevskiy
# Processing Record 21 of Set 3 | yulara
# Processing Record 22 of Set 3 | praxedis guerrero
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | timbakion
# City not found. Skipping...
# Processing Record 25 of Set 3 | ginir
# Processing Record 26 of Set 3 | santa cruz
# Processing Record 27 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 3 | gat
# Processing Record 29 of Set 3 | port elizabeth
# Processing Record 30 of Set 3 | arraial do cabo
# Processing Record 31 of Set 3 | kijang
# Processing Record 32 of Set 3 | tautira
# Processing Record 33 of Set 3 | port keats
# Processing Record 34 of Set 3 | maniitsoq
# Processing Record 35 of Set 3 | governador valadares
# Processing Record 36 of Set 3 | mehamn
# Processing Record 37 of Set 3 | klaksvik
# Processing Record 38 of Set 3 | bubaque
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | gombong
# Processing Record 41 of Set 3 | homer
# Processing Record 42 of Set 3 | coquimbo
# Processing Record 43 of Set 3 | bakuriani
# Processing Record 44 of Set 3 | saldanha
# Processing Record 45 of Set 3 | terra santa
# Processing Record 46 of Set 3 | pimentel
# Processing Record 47 of Set 3 | port-gentil
# Processing Record 48 of Set 3 | kavieng
# Processing Record 49 of Set 3 | caravelas
# Processing Record 50 of Set 3 | poya
# Processing Record 1 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 4 | carauari
# Processing Record 3 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 4 | rio gallegos
# Processing Record 5 of Set 4 | bengkulu
# Processing Record 6 of Set 4 | guaiba
# Processing Record 7 of Set 4 | togur
# Processing Record 8 of Set 4 | talnakh
# Processing Record 9 of Set 4 | maloshuyka
# City not found. Skipping...
# Processing Record 10 of Set 4 | vaini
# Processing Record 11 of Set 4 | stromness
# Processing Record 12 of Set 4 | bella union
# Processing Record 13 of Set 4 | catemaco
# Processing Record 14 of Set 4 | basco
# Processing Record 15 of Set 4 | geraldton
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | hasaki
# Processing Record 18 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 4 | ferrol
# Processing Record 20 of Set 4 | quatre cocos
# Processing Record 21 of Set 4 | ullapool
# Processing Record 22 of Set 4 | preobrazheniye
# Processing Record 23 of Set 4 | mungwi
# Processing Record 24 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 4 | norman wells
# Processing Record 26 of Set 4 | qaanaaq
# Processing Record 27 of Set 4 | komsomolskiy
# Processing Record 28 of Set 4 | college
# Processing Record 29 of Set 4 | cabo san lucas
# Processing Record 30 of Set 4 | houston
# Processing Record 31 of Set 4 | hobyo
# Processing Record 32 of Set 4 | kaitangata
# Processing Record 33 of Set 4 | pakxan
# Processing Record 34 of Set 4 | dwarka
# Processing Record 35 of Set 4 | nantucket
# Processing Record 36 of Set 4 | emborion
# Processing Record 37 of Set 4 | oudtshoorn
# Processing Record 38 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 4 | puerto baquerizo moreno
# Processing Record 40 of Set 4 | benghazi
# Processing Record 41 of Set 4 | itambe
# Processing Record 42 of Set 4 | agnibilekrou
# Processing Record 43 of Set 4 | yar-sale
# Processing Record 44 of Set 4 | dongying
# Processing Record 45 of Set 4 | cape town
# Processing Record 46 of Set 4 | atuona
# Processing Record 47 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 48 of Set 4 | makaha
# Processing Record 49 of Set 4 | comodoro rivadavia
# Processing Record 50 of Set 4 | phuntsholing
# Processing Record 1 of Set 5 | san patricio
# Processing Record 2 of Set 5 | avarua
# Processing Record 3 of Set 5 | atambua
# Processing Record 4 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 5 | bilma
# Processing Record 6 of Set 5 | koumac
# Processing Record 7 of Set 5 | korla
# Processing Record 8 of Set 5 | oranjemund
# Processing Record 9 of Set 5 | bilibino
# Processing Record 10 of Set 5 | mar del plata
# Processing Record 11 of Set 5 | nogliki
# Processing Record 12 of Set 5 | majene
# Processing Record 13 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 5 | rocha
# Processing Record 15 of Set 5 | sohagpur
# Processing Record 16 of Set 5 | khatanga
# Processing Record 17 of Set 5 | ankazobe
# Processing Record 18 of Set 5 | kroya
# Processing Record 19 of Set 5 | ilo
# Processing Record 20 of Set 5 | boa vista
# Processing Record 21 of Set 5 | luderitz
# Processing Record 22 of Set 5 | san juan
# Processing Record 23 of Set 5 | palmer
# Processing Record 24 of Set 5 | nagua
# Processing Record 25 of Set 5 | dera bugti
# Processing Record 26 of Set 5 | avera
# Processing Record 27 of Set 5 | ixtapa
# Processing Record 28 of Set 5 | qaqortoq
# Processing Record 29 of Set 5 | omboue
# Processing Record 30 of Set 5 | faya
# Processing Record 31 of Set 5 | edd
# Processing Record 32 of Set 5 | marsa matruh
# Processing Record 33 of Set 5 | mandera
# Processing Record 34 of Set 5 | upernavik
# Processing Record 35 of Set 5 | scarborough
# Processing Record 36 of Set 5 | awbari
# Processing Record 37 of Set 5 | circleville
# Processing Record 38 of Set 5 | medea
# Processing Record 39 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 5 | kropotkin
# Processing Record 41 of Set 5 | jinchengjiang
# City not found. Skipping...
# Processing Record 42 of Set 5 | upata
# Processing Record 43 of Set 5 | nanortalik
# Processing Record 44 of Set 5 | szentmartonkata
# Processing Record 45 of Set 5 | luang prabang
# Processing Record 46 of Set 5 | riyadh
# Processing Record 47 of Set 5 | port hardy
# Processing Record 48 of Set 5 | vila franca do campo
# Processing Record 49 of Set 5 | lorengau
# Processing Record 50 of Set 5 | burns lake
# Processing Record 1 of Set 6 | butembo
# Processing Record 2 of Set 6 | cidreira
# Processing Record 3 of Set 6 | kyaikto
# Processing Record 4 of Set 6 | mogadishu
# Processing Record 5 of Set 6 | luwuk
# Processing Record 6 of Set 6 | north bend
# Processing Record 7 of Set 6 | lucapa
# Processing Record 8 of Set 6 | jorochito
# Processing Record 9 of Set 6 | mildura
# Processing Record 10 of Set 6 | kishtwar
# Processing Record 11 of Set 6 | sorland
# Processing Record 12 of Set 6 | ancud
# Processing Record 13 of Set 6 | dikson
# Processing Record 14 of Set 6 | shihezi
# Processing Record 15 of Set 6 | naze
# Processing Record 16 of Set 6 | olafsvik
# Processing Record 17 of Set 6 | victoria
# Processing Record 18 of Set 6 | chernyshevskiy
# Processing Record 19 of Set 6 | tairua
# Processing Record 20 of Set 6 | mareeba
# Processing Record 21 of Set 6 | nabire
# Processing Record 22 of Set 6 | khasan
# Processing Record 23 of Set 6 | ola
# Processing Record 24 of Set 6 | kasungu
# Processing Record 25 of Set 6 | waipawa
# Processing Record 26 of Set 6 | alirajpur
# Processing Record 27 of Set 6 | marawi
# Processing Record 28 of Set 6 | paranaiba
# Processing Record 29 of Set 6 | bandarbeyla
# Processing Record 30 of Set 6 | nome
# Processing Record 31 of Set 6 | cockburn town
# Processing Record 32 of Set 6 | erzin
# Processing Record 33 of Set 6 | lumphat
# Processing Record 34 of Set 6 | tabuk
# Processing Record 35 of Set 6 | dingzhou
# Processing Record 36 of Set 6 | krasnoselkup
# Processing Record 37 of Set 6 | airai
# Processing Record 38 of Set 6 | kangaba
# Processing Record 39 of Set 6 | la ronge
# Processing Record 40 of Set 6 | chazuta
# Processing Record 41 of Set 6 | ladwa
# Processing Record 42 of Set 6 | port hedland
# Processing Record 43 of Set 6 | hovd
# Processing Record 44 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 6 | boca do acre
# Processing Record 46 of Set 6 | salinopolis
# Processing Record 47 of Set 6 | bama
# Processing Record 48 of Set 6 | fort nelson
# Processing Record 49 of Set 6 | kruisfontein
# Processing Record 50 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 7 | abraveses
# Processing Record 2 of Set 7 | puerto pinasco
# City not found. Skipping...
# Processing Record 3 of Set 7 | bairiki
# Processing Record 4 of Set 7 | wamba
# Processing Record 5 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 7 | alice springs
# Processing Record 7 of Set 7 | chimbote
# Processing Record 8 of Set 7 | methoni
# Processing Record 9 of Set 7 | albemarle
# Processing Record 10 of Set 7 | baykit
# Processing Record 11 of Set 7 | sao filipe
# Processing Record 12 of Set 7 | yurgamysh
# Processing Record 13 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 7 | sambava
# Processing Record 15 of Set 7 | sioux lookout
# Processing Record 16 of Set 7 | tefe
# Processing Record 17 of Set 7 | bucerias
# Processing Record 18 of Set 7 | partizanskoye
# Processing Record 19 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 20 of Set 7 | sao joao da barra
# Processing Record 21 of Set 7 | bambous virieux
# Processing Record 22 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 7 | vardo
# Processing Record 24 of Set 7 | broken hill
# Processing Record 25 of Set 7 | eureka
# Processing Record 26 of Set 7 | ponta do sol
# Processing Record 27 of Set 7 | muisne
# Processing Record 28 of Set 7 | carnarvon
# Processing Record 29 of Set 7 | nhulunbuy
# Processing Record 30 of Set 7 | mount isa
# Processing Record 31 of Set 7 | chilca
# Processing Record 32 of Set 7 | ladnun
# Processing Record 33 of Set 7 | tsiroanomandidy
# Processing Record 34 of Set 7 | camapua
# Processing Record 35 of Set 7 | cayenne
# Processing Record 36 of Set 7 | baghdad
# Processing Record 37 of Set 7 | shimoda
# Processing Record 38 of Set 7 | goderich
# Processing Record 39 of Set 7 | nong khai
# Processing Record 40 of Set 7 | chifeng
# Processing Record 41 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 7 | aklavik
# Processing Record 43 of Set 7 | novikovo
# Processing Record 44 of Set 7 | port moresby
# Processing Record 45 of Set 7 | esperance
# Processing Record 46 of Set 7 | laguna
# Processing Record 47 of Set 7 | karratha
# Processing Record 48 of Set 7 | pathardih
# Processing Record 49 of Set 7 | emba
# Processing Record 50 of Set 7 | coffs harbour
# Processing Record 1 of Set 8 | sadat
# Processing Record 2 of Set 8 | constitucion
# Processing Record 3 of Set 8 | lerwick
# Processing Record 4 of Set 8 | kabinda
# Processing Record 5 of Set 8 | bahar
# Processing Record 6 of Set 8 | tuntum
# Processing Record 7 of Set 8 | tilichiki
# Processing Record 8 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 8 | grong
# Processing Record 10 of Set 8 | ambilobe
# Processing Record 11 of Set 8 | garowe
# Processing Record 12 of Set 8 | sumkino
# Processing Record 13 of Set 8 | constantine
# Processing Record 14 of Set 8 | nizhniy kuranakh
# Processing Record 15 of Set 8 | formosa
# Processing Record 16 of Set 8 | ajaccio
# Processing Record 17 of Set 8 | palauig
# Processing Record 18 of Set 8 | puerto del rosario
# Processing Record 19 of Set 8 | troitsko-pechorsk
# Processing Record 20 of Set 8 | miri
# Processing Record 21 of Set 8 | boyolangu
# Processing Record 22 of Set 8 | komsomolets
# Processing Record 23 of Set 8 | uzhur
# Processing Record 24 of Set 8 | tavistock
# Processing Record 25 of Set 8 | igarka
# Processing Record 26 of Set 8 | ketchikan
# Processing Record 27 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 8 | redlands
# Processing Record 29 of Set 8 | pisco
# Processing Record 30 of Set 8 | morant bay
# Processing Record 31 of Set 8 | cullera
# Processing Record 32 of Set 8 | uusikaupunki
# Processing Record 33 of Set 8 | hamilton
# Processing Record 34 of Set 8 | namatanai
# Processing Record 35 of Set 8 | mountain home
# Processing Record 36 of Set 8 | zhoucheng
# Processing Record 37 of Set 8 | shirvan
# Processing Record 38 of Set 8 | vagur
# Processing Record 39 of Set 8 | isangel
# Processing Record 40 of Set 8 | stornoway
# Processing Record 41 of Set 8 | port lincoln
# Processing Record 42 of Set 8 | severnyy
# Processing Record 43 of Set 8 | kalabo
# Processing Record 44 of Set 8 | loandjili
# Processing Record 45 of Set 8 | buala
# Processing Record 46 of Set 8 | leua
# Processing Record 47 of Set 8 | katy
# Processing Record 48 of Set 8 | ciudad guayana
# Processing Record 49 of Set 8 | beya
# Processing Record 50 of Set 8 | yumen
# Processing Record 1 of Set 9 | warrnambool
# Processing Record 2 of Set 9 | rocky mountain house
# Processing Record 3 of Set 9 | jinchang
# Processing Record 4 of Set 9 | ballina
# Processing Record 5 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 6 of Set 9 | bayburt
# Processing Record 7 of Set 9 | mount gambier
# Processing Record 8 of Set 9 | yangambi
# Processing Record 9 of Set 9 | amla
# Processing Record 10 of Set 9 | wewak
# Processing Record 11 of Set 9 | caracollo
# Processing Record 12 of Set 9 | bima
# Processing Record 13 of Set 9 | boguchany
# Processing Record 14 of Set 9 | la palma
# Processing Record 15 of Set 9 | dunkirk
# Processing Record 16 of Set 9 | marsaxlokk
# Processing Record 17 of Set 9 | kui buri
# Processing Record 18 of Set 9 | betsiamites
# Processing Record 19 of Set 9 | hirara
# Processing Record 20 of Set 9 | terrace bay
# Processing Record 21 of Set 9 | pafos
# Processing Record 22 of Set 9 | shkotovo-26
# City not found. Skipping...
# Processing Record 23 of Set 9 | autazes
# Processing Record 24 of Set 9 | grande-riviere
# City not found. Skipping...
# Processing Record 25 of Set 9 | yeniseysk
# Processing Record 26 of Set 9 | berdigestyakh
# Processing Record 27 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 9 | cortez
# Processing Record 29 of Set 9 | abu samrah
# Processing Record 30 of Set 9 | praia
# Processing Record 31 of Set 9 | leh
# Processing Record 32 of Set 9 | hay river
# Processing Record 33 of Set 9 | tiksi
# Processing Record 34 of Set 9 | touros
# Processing Record 35 of Set 9 | samarai
# Processing Record 36 of Set 9 | kichera
# Processing Record 37 of Set 9 | tokonou
# Processing Record 38 of Set 9 | batagay-alyta
# Processing Record 39 of Set 9 | dessalines
# Processing Record 40 of Set 9 | vestmannaeyjar
# Processing Record 41 of Set 9 | berlevag
# Processing Record 42 of Set 9 | alofi
# Processing Record 43 of Set 9 | lethem
# Processing Record 44 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 45 of Set 9 | kemijarvi
# Processing Record 46 of Set 9 | susanville
# Processing Record 47 of Set 9 | alekseyevsk
# Processing Record 48 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 9 | anito
# Processing Record 50 of Set 9 | codrington
# Processing Record 1 of Set 10 | margate
# Processing Record 2 of Set 10 | saint-pierre
# Processing Record 3 of Set 10 | berezna
# Processing Record 4 of Set 10 | krasnyy chikoy
# Processing Record 5 of Set 10 | manavalakurichi
# Processing Record 6 of Set 10 | portland
# Processing Record 7 of Set 10 | labuhan
# Processing Record 8 of Set 10 | simao
# Processing Record 9 of Set 10 | vao
# Processing Record 10 of Set 10 | maiduguri
# Processing Record 11 of Set 10 | san carlos de bariloche
# Processing Record 12 of Set 10 | skiros
# City not found. Skipping...
# Processing Record 13 of Set 10 | praia da vitoria
# Processing Record 14 of Set 10 | halifax
# Processing Record 15 of Set 10 | wuwei
# Processing Record 16 of Set 10 | madison
# Processing Record 17 of Set 10 | port blair
# Processing Record 18 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 10 | bosaso
# Processing Record 20 of Set 10 | hwange
# Processing Record 21 of Set 10 | senneterre
# Processing Record 22 of Set 10 | taltal
# Processing Record 23 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 24 of Set 10 | sur
# Processing Record 25 of Set 10 | tobermory
# Processing Record 26 of Set 10 | namibe
# Processing Record 27 of Set 10 | khlung
# Processing Record 28 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 29 of Set 10 | krasnozerskoye
# Processing Record 30 of Set 10 | kerema
# Processing Record 31 of Set 10 | sinnamary
# Processing Record 32 of Set 10 | manacapuru
# Processing Record 33 of Set 10 | yuzhno-kurilsk
# Processing Record 34 of Set 10 | mizpe ramon
# City not found. Skipping...
# Processing Record 35 of Set 10 | plettenberg bay
# Processing Record 36 of Set 10 | gondanglegi
# Processing Record 37 of Set 10 | tigil
# Processing Record 38 of Set 10 | batagay
# Processing Record 39 of Set 10 | saint-augustin
# Processing Record 40 of Set 10 | san andres
# Processing Record 41 of Set 10 | tiznit
# Processing Record 42 of Set 10 | kushiro
# Processing Record 43 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 44 of Set 10 | san policarpo
# Processing Record 45 of Set 10 | santiago de cao
# Processing Record 46 of Set 10 | tychy
# Processing Record 47 of Set 10 | los llanos de aridane
# Processing Record 48 of Set 10 | umtata
# Processing Record 49 of Set 10 | patacamaya
# Processing Record 50 of Set 10 | keshan
# City not found. Skipping...
# Processing Record 1 of Set 11 | worland
# Processing Record 2 of Set 11 | dingle
# Processing Record 3 of Set 11 | farafangana
# Processing Record 4 of Set 11 | jutai
# Processing Record 5 of Set 11 | tucuman
# Processing Record 6 of Set 11 | atikokan
# Processing Record 7 of Set 11 | ukiah
# Processing Record 8 of Set 11 | eyl
# Processing Record 9 of Set 11 | novouzensk
# Processing Record 10 of Set 11 | kavaratti
# Processing Record 11 of Set 11 | paamiut
# Processing Record 12 of Set 11 | cabra
# Processing Record 13 of Set 11 | aripuana
# Processing Record 14 of Set 11 | platanos
# Processing Record 15 of Set 11 | guelengdeng
# City not found. Skipping...
# Processing Record 16 of Set 11 | vila velha
# Processing Record 17 of Set 11 | erfurt
# Processing Record 18 of Set 11 | san isidro
# Processing Record 19 of Set 11 | newberry
# Processing Record 20 of Set 11 | zapolyarnyy
# Processing Record 21 of Set 11 | torbay
# Processing Record 22 of Set 11 | lagoa
# Processing Record 23 of Set 11 | talara
# Processing Record 24 of Set 11 | neuquen
# Processing Record 25 of Set 11 | ovalle
# Processing Record 26 of Set 11 | birjand
# Processing Record 27 of Set 11 | novaya ladoga
# Processing Record 28 of Set 11 | freetown
# Processing Record 29 of Set 11 | opobo
# City not found. Skipping...
# Processing Record 30 of Set 11 | vigrestad
# Processing Record 31 of Set 11 | mutis
# Processing Record 32 of Set 11 | vostok
# Processing Record 33 of Set 11 | tempio pausania
# Processing Record 34 of Set 11 | davenda
# Processing Record 35 of Set 11 | belmonte
# Processing Record 36 of Set 11 | catabola
# Processing Record 37 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 38 of Set 11 | ulladulla
# Processing Record 39 of Set 11 | chowchilla
# Processing Record 40 of Set 11 | esso
# Processing Record 41 of Set 11 | malatya
# Processing Record 42 of Set 11 | provideniya
# Processing Record 43 of Set 11 | beringovskiy
# Processing Record 44 of Set 11 | gavrilov posad
# Processing Record 45 of Set 11 | ojinaga
# Processing Record 46 of Set 11 | natchez
# Processing Record 47 of Set 11 | tabou
# Processing Record 48 of Set 11 | zemio
# Processing Record 49 of Set 11 | high prairie
# Processing Record 50 of Set 11 | dalmau
# Processing Record 1 of Set 12 | shubarshi
# Processing Record 2 of Set 12 | ukhta
# Processing Record 3 of Set 12 | zarubino
# Processing Record 4 of Set 12 | volnovakha
# Processing Record 5 of Set 12 | ponta delgada
# Processing Record 6 of Set 12 | carballo
# Processing Record 7 of Set 12 | diffa
# Processing Record 8 of Set 12 | tuy hoa
# Processing Record 9 of Set 12 | nuuk
# Processing Record 10 of Set 12 | kupang
# Processing Record 11 of Set 12 | chicama
# Processing Record 12 of Set 12 | korcula
# Processing Record 13 of Set 12 | contai
# Processing Record 14 of Set 12 | san jeronimo
# Processing Record 15 of Set 12 | sisimiut
# Processing Record 16 of Set 12 | karatu
# Processing Record 17 of Set 12 | narsaq
# Processing Record 18 of Set 12 | channel-port aux basques
# Processing Record 19 of Set 12 | longhua
# Processing Record 20 of Set 12 | baruun-urt
# Processing Record 21 of Set 12 | bathsheba
# Processing Record 22 of Set 12 | khorinsk
# Processing Record 23 of Set 12 | padang
# Processing Record 24 of Set 12 | itarema
# Processing Record 25 of Set 12 | sao mateus
# Processing Record 26 of Set 12 | glenwood springs
# Processing Record 27 of Set 12 | tamworth
# Processing Record 28 of Set 12 | marsh harbour
# Processing Record 29 of Set 12 | khorramshahr
# Processing Record 30 of Set 12 | roald
# Processing Record 31 of Set 12 | barranca
# Processing Record 32 of Set 12 | watertown
# Processing Record 33 of Set 12 | chapais
# Processing Record 34 of Set 12 | islamkot
# Processing Record 35 of Set 12 | volgodonsk
# Processing Record 36 of Set 12 | mixtequilla
# City not found. Skipping...
# Processing Record 37 of Set 12 | merrill
# Processing Record 38 of Set 12 | manono
# Processing Record 39 of Set 12 | kralendijk
# Processing Record 40 of Set 12 | waingapu
# Processing Record 41 of Set 12 | balaipungut
# Processing Record 42 of Set 12 | hokitika
# Processing Record 43 of Set 12 | penzance
# Processing Record 44 of Set 12 | astana
# Processing Record 45 of Set 12 | gorontalo
# Processing Record 46 of Set 12 | sola
# Processing Record 47 of Set 12 | pozo colorado
# Processing Record 48 of Set 12 | asosa
# Processing Record 49 of Set 12 | biltine
# Processing Record 50 of Set 12 | the valley
# Processing Record 1 of Set 13 | guerrero negro
# Processing Record 2 of Set 13 | orel-izumrud
# Processing Record 3 of Set 13 | shaunavon
# Processing Record 4 of Set 13 | waspan
# Processing Record 5 of Set 13 | bridgetown
# Processing Record 6 of Set 13 | kihei
# Processing Record 7 of Set 13 | thiruvananthapuram
# Processing Record 8 of Set 13 | coahuayana
# Processing Record 9 of Set 13 | muhoroni
# Processing Record 10 of Set 13 | hailar
# Processing Record 11 of Set 13 | nambucca heads
# Processing Record 12 of Set 13 | cherskiy
# Processing Record 13 of Set 13 | the hammocks
# Processing Record 14 of Set 13 | urucara
# Processing Record 15 of Set 13 | nouadhibou
# Processing Record 16 of Set 13 | helong
# Processing Record 17 of Set 13 | mackenzie
# Processing Record 18 of Set 13 | santa pola
# Processing Record 19 of Set 13 | sabang
# Processing Record 20 of Set 13 | najran
# Processing Record 21 of Set 13 | el penon
# Processing Record 22 of Set 13 | wakkanai
# Processing Record 23 of Set 13 | morondava
# Processing Record 24 of Set 13 | pacific grove
# Processing Record 25 of Set 13 | raga
# Processing Record 26 of Set 13 | aswan
# Processing Record 27 of Set 13 | lensk
# Processing Record 28 of Set 13 | lincoln
# Processing Record 29 of Set 13 | maragogi
# Processing Record 30 of Set 13 | mitsamiouli
# Processing Record 31 of Set 13 | vaitape
# Processing Record 32 of Set 13 | savannah bight
# Processing Record 33 of Set 13 | benito juarez
# Processing Record 34 of Set 13 | chute-aux-outardes
# Processing Record 35 of Set 13 | mandalgovi
# Processing Record 36 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 13 | ust-maya
# Processing Record 38 of Set 13 | inirida
# Processing Record 39 of Set 13 | odweyne
# Processing Record 40 of Set 13 | challans
# Processing Record 41 of Set 13 | thinadhoo
# Processing Record 42 of Set 13 | atar
# Processing Record 43 of Set 13 | katherine
# Processing Record 44 of Set 13 | manaure
# Processing Record 45 of Set 13 | berea
# Processing Record 46 of Set 13 | santa ana
# Processing Record 47 of Set 13 | igrim
# Processing Record 48 of Set 13 | soubre
# Processing Record 49 of Set 13 | cancun
# Processing Record 50 of Set 13 | beira
# Processing Record 1 of Set 14 | marietta
# Processing Record 2 of Set 14 | sardinata
# Processing Record 3 of Set 14 | kangaatsiaq
# Processing Record 4 of Set 14 | dien bien
# City not found. Skipping...
# Processing Record 5 of Set 14 | methala
# Processing Record 6 of Set 14 | cabedelo
# Processing Record 7 of Set 14 | ridgecrest
# Processing Record 8 of Set 14 | polson
# Processing Record 9 of Set 14 | jevargi
# Processing Record 10 of Set 14 | melendugno
# Processing Record 11 of Set 14 | nong kung si
# Processing Record 12 of Set 14 | oeiras
# Processing Record 13 of Set 14 | taybad
# Processing Record 14 of Set 14 | tianpeng
# Processing Record 15 of Set 14 | solhan
# Processing Record 16 of Set 14 | kodinar
# Processing Record 17 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 18 of Set 14 | kousseri
# Processing Record 19 of Set 14 | pochutla
# Processing Record 20 of Set 14 | rambha
# Processing Record 21 of Set 14 | kosonsoy
# Processing Record 22 of Set 14 | jackson
# Processing Record 23 of Set 14 | whitianga
# Processing Record 24 of Set 14 | nerchinsk
# Processing Record 25 of Set 14 | kuminskiy
# Processing Record 26 of Set 14 | nanganga
# Processing Record 27 of Set 14 | broome
# Processing Record 28 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 29 of Set 14 | sao felix do xingu
# Processing Record 30 of Set 14 | colares
# Processing Record 31 of Set 14 | puerto leguizamo
# Processing Record 32 of Set 14 | ust-ordynskiy
# Processing Record 33 of Set 14 | zhezkazgan
# Processing Record 34 of Set 14 | kovilpatti
# Processing Record 35 of Set 14 | harper
# Processing Record 36 of Set 14 | zirgan
# Processing Record 37 of Set 14 | san cristobal
# Processing Record 38 of Set 14 | kudahuvadhoo
# Processing Record 39 of Set 14 | nouakchott
# Processing Record 40 of Set 14 | saint-joseph
# Processing Record 41 of Set 14 | tukrah
# Processing Record 42 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 14 | macusani
# Processing Record 44 of Set 14 | ilulissat
# Processing Record 45 of Set 14 | dandong
# Processing Record 46 of Set 14 | tura
# Processing Record 47 of Set 14 | arawa
# Processing Record 48 of Set 14 | kieta
# Processing Record 49 of Set 14 | high rock
# Processing Record 50 of Set 14 | makakilo city
# Processing Record 1 of Set 15 | deputatskiy
# Processing Record 2 of Set 15 | bangassou
# Processing Record 3 of Set 15 | novorzhev
# Processing Record 4 of Set 15 | quemado de guines
# Processing Record 5 of Set 15 | christchurch
# Processing Record 6 of Set 15 | lucea
# Processing Record 7 of Set 15 | sulangan
# Processing Record 8 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 9 of Set 15 | turukhansk
# Processing Record 10 of Set 15 | graaff-reinet
# Processing Record 11 of Set 15 | tomatlan
# Processing Record 12 of Set 15 | melfi
# Processing Record 13 of Set 15 | washington
# Processing Record 14 of Set 15 | san jose
# Processing Record 15 of Set 15 | xiaoweizhai
# Processing Record 16 of Set 15 | antropovo
# Processing Record 17 of Set 15 | jinka
# Processing Record 18 of Set 15 | gornyy
# Processing Record 19 of Set 15 | lebedyn
# Processing Record 20 of Set 15 | fandriana
# Processing Record 21 of Set 15 | cassilandia
# Processing Record 22 of Set 15 | sovetskiy
# Processing Record 23 of Set 15 | isla vista
# Processing Record 24 of Set 15 | mezen
# Processing Record 25 of Set 15 | port arthur
# Processing Record 26 of Set 15 | yanam
# Processing Record 27 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 15 | santa maria da boa vista
# Processing Record 29 of Set 15 | batemans bay
# Processing Record 30 of Set 15 | imeni poliny osipenko
# Processing Record 31 of Set 15 | doha
# Processing Record 32 of Set 15 | san matias
# Processing Record 33 of Set 15 | aksu
# Processing Record 34 of Set 15 | voh
# Processing Record 35 of Set 15 | kholm
# Processing Record 36 of Set 15 | rawson
# Processing Record 37 of Set 15 | amudat
# Processing Record 38 of Set 15 | chepareria
# Processing Record 39 of Set 15 | copiapo
# Processing Record 40 of Set 15 | bokoro
# Processing Record 41 of Set 15 | catamarca
# Processing Record 42 of Set 15 | kargil
# Processing Record 43 of Set 15 | genhe
# Processing Record 44 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 15 | kardla
# Processing Record 46 of Set 15 | grindavik
# Processing Record 47 of Set 15 | riaba
# City not found. Skipping...
# Processing Record 48 of Set 15 | dhali
# Processing Record 49 of Set 15 | adrar
# Processing Record 50 of Set 15 | asau
# Processing Record 1 of Set 16 | sabzevar
# Processing Record 2 of Set 16 | hervey bay
# Processing Record 3 of Set 16 | lata
# Processing Record 4 of Set 16 | mawlaik
# Processing Record 5 of Set 16 | jalu
# Processing Record 6 of Set 16 | olga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Moa      CU  20.6569  -74.9403     82.87        78          82
# 1  Puerto Ayora      EC  -0.7393  -90.3518     78.76        85          38
# 2        Vanimo      PG  -2.6741  141.3028     81.05        77          54
# 3    Bredasdorp      ZA -34.5322   20.0403     55.13        91         100
# 4          Uige      AO  -7.6087   15.0613     65.34        75          99
# 5     Fairbanks      US  64.8378 -147.7164     61.09        66          75
# 6   East London      ZA -33.0153   27.9116     66.42        50          29
# 7      Meulaboh      ID   4.1363   96.1285     76.98        85         100
# 8         Bowen      AU -20.0167  148.2333     62.65        61           0
# 9         Hanko      FI  59.8333   22.9500     66.06        95         100
#
#    Wind Speed Current Description
# 0       12.73       broken clouds
# 1        5.99    scattered clouds
# 2        4.41       broken clouds
# 3        9.31          light rain
# 4        2.64     overcast clouds
# 5        9.22       broken clouds
# 6       11.68    scattered clouds
# 7        5.30     overcast clouds
# 8        5.17           clear sky
# 9        6.87       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
